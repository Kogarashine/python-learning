# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Фрукт': ['Яблука', 'Банани', 'Вишні'],
        'Кількість': [10, 25, 15]}
df = pd.DataFrame(data)

print("Моя перша таблиця:")
display(df)


df.plot(x='Фрукт', y='Кількість', kind='bar', color='orange')
plt.show()
# Out:
# Моя перша таблиця:
#     Фрукт  Кількість
# 0  Яблука         10
# 1  Банани         25
# 2   Вишні         15
